# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
file_names = {"file_1": "/Users/KliavinekSS/Documents/GitHub/signal-processing/frequency_filt_90.dat",\
              "file_2": "/Users/KliavinekSS/Documents/GitHub/signal-processing/frequency.dat"}
plots = {}
for key in file_names.keys():
    file = open(file_names[key], "r")
    index = []
    real_part = []
    imagine_part = []
    amplitude =[]
    for i, line in enumerate(file):
        if i>0:
            index.append(int(line.split()[0]))
            real_part.append(float(line.split()[1]))
            imagine_part.append(float(line.split()[2]))
            amplitude.append(float(line.split()[3]))
    file.close()
    plots[key] = [np.array(index), np.array(real_part), np.array(imagine_part), np.array(amplitude)]
labels = {0: "Real Part", 1:"Imagine Part", 2:"Amplitude"}
for i in range(3):
    mpl.rcParams['font.size'] = 20
    plt.figure(figsize=(10,8))
    axes = plt.gca()
    plt.plot(plots["file_1"][0],plots["file_2"][i+1], 'g')
    plt.plot(plots["file_1"][0],plots["file_2"][i+1] - plots["file_1"][i+1], 'b')
    plt.xlabel("Index")
    plt.ylabel(labels[i])
    plt.show()

# %%
file_names = {"file_1": "/Users/KliavinekSS/Documents/GitHub/signal-processing/signal_filt_90.dat",\
              "file_2": "/Users/KliavinekSS/Documents/GitHub/signal-processing/signal.dat"}
plots = {}
for key in file_names.keys():
    file = open(file_names[key], "r")
    index = []
    real_part = []
    imagine_part = []
    amplitude =[]
    for i, line in enumerate(file):
        if i>0:
            index.append(int(line.split()[0]))
            real_part.append(float(line.split()[1]))
            imagine_part.append(float(line.split()[2]))
            amplitude.append(float(line.split()[3]))
    file.close()
    plots[key] = [np.array(index), np.array(real_part), np.array(imagine_part), np.array(amplitude)]
labels = {0: "Real Part", 1:"Imagine Part", 2:"Amplitude"}
for i in range(3):
    mpl.rcParams['font.size'] = 20
    plt.figure(figsize=(10,8))
    axes = plt.gca()
    plt.plot(plots["file_1"][0],plots["file_2"][i+1], 'g')
    plt.plot(plots["file_1"][0],plots["file_2"][i+1] - plots["file_1"][i+1], 'b')
    plt.xlabel("Index")
    plt.ylabel(labels[i])
    plt.show()
